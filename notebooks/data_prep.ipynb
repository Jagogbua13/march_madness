# %%
import pandas as pd
import numpy as np
# Out:
# /anaconda3/envs/python36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /anaconda3/envs/python36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = pd.read_csv('combined_stats.csv')
#df['TEAM'] = df["TEAM"].str.lower()
#df.to_csv('combined_stats.csv',encoding='utf-8')

# %%
df = pd.read_csv('combined_stats.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                TEAM  GP   PPG  FGM-game  FGA-game  \
# 0           0             0             gonzaga  33  88.8      32.2      60.5
# 1           1             1  south dakota state  32  84.9      29.9      59.4
# 2           2             2              dayton  32  72.9      27.3      54.2
# 3           3             3             belmont  31  87.4      31.8      63.7
# 4           4             4    georgia southern  33  82.6      30.7      61.5
#
#    FGM-total  FGA-total    FG%    ...        2P%   PPS  FG%.adj  \
# 0       1062       1997  0.532    ...      0.623  1.47    0.596
# 1        957       1901  0.503    ...      0.568  1.43    0.587
# 2        872       1734  0.503    ...      0.592  1.35    0.561
# 3        987       1976  0.499    ...      0.599  1.37    0.582
# 4       1012       2028  0.499    ...      0.579  1.34    0.549
#
#                  team  games_played assist  assist_per_game  turnover  \
# 0             Gonzaga            33    601             18.2       342
# 1  South Dakota State            32    476             14.9       379
# 2              Dayton            32    529             16.5       403
# 3             Belmont            31    616             19.9       360
# 4    Georgia Southern            33    403             12.2       452
#
#    turnover_per_game  assist/to
# 0               10.4       1.76
# 1               11.8       1.26
# 2               12.6       1.31
# 3               11.6       1.71
# 4               13.7       0.89
#
# [5 rows x 22 columns]

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'TEAM', 'GP', 'PPG', 'FGM-game',
#        'FGA-game', 'FGM-total', 'FGA-total', 'FG%', '2PM', '2PA', '2P%', 'PPS',
#        'FG%.adj', 'team', 'games_played', 'assist', 'assist_per_game',
#        'turnover', 'turnover_per_game', 'assist/to'],
#       dtype='object')

# %%
def school_list():
    list_schools = df['TEAM'].values.tolist()
    return(list_schools)

# %%
test = school_list()
test
# Out:
# ['gonzaga',
#  'south dakota state',
#  'dayton',
#  'belmont',
#  'georgia southern',
#  'tennessee',
#  'montana',
#  'murray state',
#  'yale',
#  'loyola-chicago',
#  'wofford',
#  'liberty',
#  'michigan state',
#  'gardner-webb',
#  'hofstra',
#  'east tennessee state',
#  'utah valley',
#  'little rock',
#  'charleston',
#  'lipscomb',
#  'northeastern',
#  'lehigh',
#  'creighton',
#  'northern kentucky',
#  'purdue fort wayne',
#  'boston university',
#  'colgate',
#  'kentucky',
#  'virginia',
#  'fairleigh dickinson',
#  'duke',
#  'iowa state',
#  'colorado state',
#  'furman',
#  'weber state',
#  'virginia tech',
#  'omaha',
#  'william & mary',
#  'american',
#  'abilene christian',
#  'utah state',
#  "saint mary's",
#  'umass lowell',
#  'austin peay',
#  'samford',
#  'mississippi state',
#  'richmond',
#  'texas tech',
#  'northern illinois',
#  'drake',
#  'ball state',
#  'boise state',
#  'xavier',
#  'byu',
#  'southern miss',
#  'san francisco',
#  'depaul',
#  'southern illinois',
#  'incarnate word',
#  'georgia state',
#  'nevada',
#  'oakland',
#  'north dakota',
#  'utah',
#  'north carolina',
#  'ucf',
#  'oregon state',
#  'buffalo',
#  'holy cross',
#  'csu northridge',
#  'northern colorado',
#  'kansas',
#  'jacksonville state',
#  'lsu',
#  'radford',
#  'south alabama',
#  'drexel',
#  'usc',
#  'sacred heart',
#  'uic',
#  'ole miss',
#  'san diego',
#  'uc irvine',
#  'indiana',
#  'north carolina a&t',
#  'new mexico state',
#  'delaware',
#  'loyola (md)',
#  'marquette',
#  'vermont',
#  'tcu',
#  'nc state',
#  'harvard',
#  'loyola marymount',
#  'ucla',
#  'csu fullerton',
#  'colorado',
#  'unc greensboro',
#  'lamar',
#  'houston baptist',
#  'north dakota state',
#  'montana state',
#  'campbell',
#  'north carolina central',
#  'oral roberts',
#  'winthrop',
#  'jacksonville',
#  'hartford',
#  'iowa',
#  'toledo',
#  'maryland',
#  'western carolina',
#  'appalachian state',
#  "st. john's",
#  'fresno state',
#  'central michigan',
#  'grand canyon',
#  'pennsylvania',
#  'uab',
#  'uc santa barbara',
#  'iona',
#  'stanford',
#  'wisconsin',
#  'green bay',
#  'iupui',
#  'florida gulf coast',
#  'washington',
#  'clemson',
#  'columbia',
#  'memphis',
#  'dartmouth',
#  'ul monroe',
#  'air force',
#  'missouri state',
#  'michigan',
#  "hawai'i",
#  'mercer',
#  'california baptist',
#  'mcneese',
#  'valparaiso',
#  'presbyterian',
#  'coastal carolina',
#  'bucknell',
#  'troy',
#  'texas southern',
#  'oregon',
#  'auburn',
#  'lafayette',
#  'eastern michigan',
#  'marist',
#  'houston',
#  'grambling',
#  'davidson',
#  'tulsa',
#  'north florida',
#  'sacramento state',
#  'washington state',
#  'rider',
#  'arizona state',
#  'idaho state',
#  'the citadel',
#  'arkansas',
#  'western kentucky',
#  'purdue',
#  'uconn',
#  'ut martin',
#  'new orleans',
#  'njit',
#  'louisiana',
#  'oklahoma',
#  'butler',
#  'george mason',
#  'santa clara',
#  'georgetown',
#  'texas state',
#  'southern utah',
#  'high point',
#  'pepperdine',
#  'uc riverside',
#  'unc wilmington',
#  'florida state',
#  'chattanooga',
#  'bowling green',
#  'brown',
#  'vcu',
#  'smu',
#  'james madison',
#  'marshall',
#  'umass',
#  'florida international',
#  'idaho',
#  'se louisiana',
#  'sam houston state',
#  'alabama',
#  'georgia',
#  'seton hall',
#  'georgia tech',
#  'indiana state',
#  'baylor',
#  'se missouri st',
#  'western illinois',
#  'southern',
#  'villanova',
#  'uc davis',
#  'stephen f. austin',
#  'norfolk state',
#  'seattle',
#  'bethune-cookman',
#  'temple',
#  'florida a&m',
#  'denver',
#  'prairie view a&m',
#  'south dakota',
#  'texas a&m',
#  'liu brooklyn',
#  'st. francis (pa)',
#  'minnesota',
#  'ohio state',
#  'ohio',
#  'wright state',
#  'cornell',
#  'elon',
#  'louisiana tech',
#  'cleveland state',
#  'san diego state',
#  'towson',
#  'canisius',
#  'north texas',
#  'miami',
#  'howard',
#  'louisville',
#  'siena',
#  'hampton',
#  'fairfield',
#  'bradley',
#  'texas',
#  'utsa',
#  'umbc',
#  'robert morris',
#  'maine',
#  'kent state',
#  'eastern illinois',
#  'cincinnati',
#  'tennessee state',
#  'long beach state',
#  'st. bonaventure',
#  'northern arizona',
#  'umkc',
#  "saint peter's",
#  'kansas state',
#  'illinois state',
#  'illinois',
#  'binghamton',
#  'missouri',
#  'eastern washington',
#  'texas a&m-cc',
#  'morehead state',
#  'south florida',
#  'rhode island',
#  'south carolina state',
#  'charleston southern',
#  'army',
#  'csu bakersfield',
#  'duquesne',
#  'nebraska',
#  'youngstown state',
#  'unlv',
#  'vmi',
#  'florida',
#  'arkansas-pine bluff',
#  'arizona',
#  'california',
#  'rice',
#  'central arkansas',
#  'western michigan',
#  'quinnipiac',
#  'boston college',
#  'eastern kentucky',
#  'portland state',
#  'providence',
#  'syracuse',
#  'oklahoma state',
#  'longwood',
#  'nicholls',
#  'south carolina',
#  'st. francis (bkn)',
#  'pacific',
#  'stony brook',
#  'new mexico',
#  'bryant',
#  'niagara',
#  'miami (oh)',
#  'evansville',
#  'vanderbilt',
#  'milwaukee',
#  'saint louis',
#  'middle tennessee',
#  'rutgers',
#  'detroit mercy',
#  'siu-edwardsville',
#  'east carolina',
#  'arkansas state',
#  'pittsburgh',
#  "mt. st. mary's",
#  'penn state',
#  'ut rio grande valley',
#  'wyoming',
#  'northern iowa',
#  'albany',
#  'tennessee tech',
#  'charlotte',
#  'monmouth',
#  'central connecticut',
#  'south carolina upstate',
#  'portland',
#  'west virginia',
#  'alcorn state',
#  'florida atlantic',
#  'cal poly',
#  'princeton',
#  'tulane',
#  'ut arlington',
#  'old dominion',
#  'navy',
#  'chicago state',
#  'akron',
#  "saint joseph's",
#  'alabama a&m',
#  'wichita state',
#  'northwestern state',
#  'manhattan',
#  'stetson',
#  'george washington',
#  'jackson state',
#  'san josé st',
#  'alabama state',
#  'unc asheville',
#  'northwestern',
#  'fordham',
#  'utep',
#  'la salle',
#  'savannah state',
#  'morgan state',
#  'wake forest',
#  'notre dame',
#  'maryland-eastern shore',
#  'north alabama',
#  'coppin state',
#  'wagner',
#  'kennesaw state',
#  'mississippi valley state',
#  'new hampshire',
#  'delaware state']

# %%
new_df = df[['FGA-game','assist_per_game','turnover_per_game']]
new_df.head()
# Out:
#    FGA-game  assist_per_game  turnover_per_game
# 0      60.5             18.2               10.4
# 1      59.4             14.9               11.8
# 2      54.2             16.5               12.6
# 3      63.7             19.9               11.6
# 4      61.5             12.2               13.7

# %%
def get_team(team):
    
    team_stat= df.loc[df['TEAM'] == team]
    new_df = team_stat[['FGA-game','assist_per_game','turnover_per_game']].values.tolist()
    stats = new_df[0]
    #print(stats)
    return(stats)

# %%
get_team('auburn')
# Out:
# [60.9, 14.4, 12.3]

# %%
def model_prep(home,away):
    home_stats = get_team(home)
    away_stats = get_team(away)
    model_list = []
    
    for x in range(0,3):
        model_list.append(home_stats[x])
        model_list.append(away_stats[x])
    model_stats= {'h_field_goals_att':model_list[0],'a_field_goals_att':model_list[1], 'h_assists':model_list[2],'a_assists':model_list[3],
                  'h_turnovers':model_list[4],'a_turnovers':model_list[5]}
    model_df = pd.DataFrame(model_stats, index=[0])
    return(model_df)
    #return(model_list)

# %%
model_prep("gonzaga","dayton")
# Out:
#    h_field_goals_att  a_field_goals_att  h_assists  a_assists  h_turnovers  \
# 0               60.5               54.2       18.2       16.5         10.4
#
#    a_turnovers
# 0         12.6

# %%
from keras.models import load_model
ncaa_model = load_model("deep_neural_ncaa_trained.h5")
# Out:
# Using TensorFlow backend.

# %%
from sklearn.externals import joblib

scaler = joblib.load("xscaler.save")

# %%
test = scaler.transform(model_prep("Gonzaga","Auburn"))
test
answer = ncaa_model.predict(test)
answer
result = np.argmax(answer,axis=1,out=None)
result
# Out:
# array([1])

# %%
def model_predict(home,away):
    
    team_stats= model_prep(home,away)
    x_valid = scaler.transform(team_stats)
    prediction= ncaa_model.predict(x_valid)
    #prediction= ncaa_model.predict(team_stats)
    result = np.argmax(prediction,axis=None,out=None)
    print(result)
    if result == 0 :
        return(f'{home} wins{result}')
    else:
        return(f'{away} wins{result}')

# %%
model_predict("Gonzaga","Auburn")
# Out:
# 1
# 'Auburn wins1'
